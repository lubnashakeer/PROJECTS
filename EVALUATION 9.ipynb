# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # IMPORTING THE DATASET

# %%
df=pd.read_csv("https://raw.githubusercontent.com/wri/global-power-plant-database/master/source_databases_csv/database_IND.csv")
df.head()
# Out:
#   country country_long                      name   gppd_idnr  capacity_mw  \
# 0     IND        India          ACME Solar Tower  WRI1020239          2.5
# 1     IND        India       ADITYA CEMENT WORKS  WRI1019881         98.0
# 2     IND        India  AES Saurashtra Windfarms  WRI1026669         39.2
# 3     IND        India               AGARTALA GT  IND0000001        135.0
# 4     IND        India              AKALTARA TPP  IND0000002       1800.0
#
#    latitude  longitude primary_fuel other_fuel1 other_fuel2  ...  \
# 0   28.1839    73.2407        Solar         NaN         NaN  ...
# 1   24.7663    74.6090         Coal         NaN         NaN  ...
# 2   21.9038    69.3732         Wind         NaN         NaN  ...
# 3   23.8712    91.3602          Gas         NaN         NaN  ...
# 4   21.9603    82.4091         Coal         Oil         NaN  ...
#
#    year_of_capacity_data  generation_gwh_2013 generation_gwh_2014  \
# ...

# %%
df['primary_fuel']
# Out:
# 0      Solar
# 1       Coal
# 2       Wind
# 3        Gas
# 4       Coal
#        ...
# 902     Coal
# 903    Solar
# 904     Wind
# 905     Coal
# 906     Wind
# Name: primary_fuel, Length: 907, dtype: object

# %%
df.shape
# Out:
# (907, 27)

# %%
df.columns
# Out:
# Index(['country', 'country_long', 'name', 'gppd_idnr', 'capacity_mw',
#        'latitude', 'longitude', 'primary_fuel', 'other_fuel1', 'other_fuel2',
#        'other_fuel3', 'commissioning_year', 'owner', 'source', 'url',
#        'geolocation_source', 'wepp_id', 'year_of_capacity_data',
#        'generation_gwh_2013', 'generation_gwh_2014', 'generation_gwh_2015',
#        'generation_gwh_2016', 'generation_gwh_2017', 'generation_gwh_2018',
#        'generation_gwh_2019', 'generation_data_source',
#        'estimated_generation_gwh'],
#       dtype='object')

# %% [markdown]
# # CHECKING THE DATTYPE OF THE COLUMNS

# %%
df.dtypes
# Out:
# country                      object
# country_long                 object
# name                         object
# gppd_idnr                    object
# capacity_mw                 float64
# latitude                    float64
# longitude                   float64
# primary_fuel                 object
# other_fuel1                  object
# other_fuel2                  object
# other_fuel3                 float64
# commissioning_year          float64
# owner                        object
# source                       object
# url                          object
# geolocation_source           object
# wepp_id                     float64
# year_of_capacity_data       float64
# generation_gwh_2013         float64
# generation_gwh_2014         float64
# generation_gwh_2015         float64
# generation_gwh_2016         float64
# generation_gwh_2017         float64
# generation_gwh_2018         float64
# generation_gwh_2019         float64
# generation_data_source       object
# ...

# %% [markdown]
# - CAPACITY_NEW IS IN FLOAT TYPE WHICH IS ACCURATE HENCE NOT ALTERING

# %% [markdown]
# # CHECKING FOR NULL VALUES

# %%
df.isnull().sum()
# Out:
# country                       0
# country_long                  0
# name                          0
# gppd_idnr                     0
# capacity_mw                   0
# latitude                     46
# longitude                    46
# primary_fuel                  0
# other_fuel1                 709
# other_fuel2                 906
# other_fuel3                 907
# commissioning_year          380
# owner                       565
# source                        0
# url                           0
# geolocation_source           19
# wepp_id                     907
# year_of_capacity_data       388
# generation_gwh_2013         907
# generation_gwh_2014         509
# generation_gwh_2015         485
# generation_gwh_2016         473
# generation_gwh_2017         467
# generation_gwh_2018         459
# generation_gwh_2019         907
# generation_data_source      458
# estimated_generation_gwh    907
# dtype: int64

# %% [markdown]
# - SEEMS LIKE THERE ARE MANY NULL VALUES , HENCE REMOVING THOSE

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 907 entries, 0 to 906
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   country                   907 non-null    object
#  1   country_long              907 non-null    object
#  2   name                      907 non-null    object
#  3   gppd_idnr                 907 non-null    object
#  4   capacity_mw               907 non-null    float64
#  5   latitude                  861 non-null    float64
#  6   longitude                 861 non-null    float64
#  7   primary_fuel              907 non-null    object
#  8   other_fuel1               198 non-null    object
#  9   other_fuel2               1 non-null      object
#  10  other_fuel3               0 non-null      float64
#  11  commissioning_year        527 non-null    float64
#  12  owner                     342 non-null    object
# ...

# %%
df.shape
# Out:
# (907, 27)

# %%
df_filled = df.fillna(df.mode().iloc[0],inplace=True)

# %%
df.isnull().sum()
# Out:
# country                       0
# country_long                  0
# name                          0
# gppd_idnr                     0
# capacity_mw                   0
# latitude                      0
# longitude                     0
# primary_fuel                  0
# other_fuel1                   0
# other_fuel2                   0
# other_fuel3                 907
# commissioning_year            0
# owner                         0
# source                        0
# url                           0
# geolocation_source            0
# wepp_id                     907
# year_of_capacity_data         0
# generation_gwh_2013         907
# generation_gwh_2014           0
# generation_gwh_2015           0
# generation_gwh_2016           0
# generation_gwh_2017           0
# generation_gwh_2018           0
# generation_gwh_2019         907
# generation_data_source        0
# estimated_generation_gwh    907
# dtype: int64

# %%
df
# Out:
#     country country_long                          name   gppd_idnr  \
# 0       IND        India              ACME Solar Tower  WRI1020239
# 1       IND        India           ADITYA CEMENT WORKS  WRI1019881
# 2       IND        India      AES Saurashtra Windfarms  WRI1026669
# 3       IND        India                   AGARTALA GT  IND0000001
# 4       IND        India                  AKALTARA TPP  IND0000002
# ..      ...          ...                           ...         ...
# 902     IND        India                  YERMARUS TPP  IND0000513
# 903     IND        India  Yelesandra Solar Power Plant  WRI1026222
# 904     IND        India  Yelisirur wind power project  WRI1026776
# 905     IND        India                   ZAWAR MINES  WRI1019901
# 906     IND        India       iEnergy Theni Wind Farm  WRI1026761
#
#      capacity_mw  latitude  longitude primary_fuel other_fuel1 other_fuel2  \
# 0            2.5   28.1839    73.2407        Solar         Oil         Oil
# ...

# %%
df_filled = df.fillna(df.mean().iloc[0],inplace=True)

# %%
df
# Out:
#     country country_long                          name   gppd_idnr  \
# 0       IND        India              ACME Solar Tower  WRI1020239
# 1       IND        India           ADITYA CEMENT WORKS  WRI1019881
# 2       IND        India      AES Saurashtra Windfarms  WRI1026669
# 3       IND        India                   AGARTALA GT  IND0000001
# 4       IND        India                  AKALTARA TPP  IND0000002
# ..      ...          ...                           ...         ...
# 902     IND        India                  YERMARUS TPP  IND0000513
# 903     IND        India  Yelesandra Solar Power Plant  WRI1026222
# 904     IND        India  Yelisirur wind power project  WRI1026776
# 905     IND        India                   ZAWAR MINES  WRI1019901
# 906     IND        India       iEnergy Theni Wind Farm  WRI1026761
#
#      capacity_mw  latitude  longitude primary_fuel other_fuel1 other_fuel2  \
# 0            2.5   28.1839    73.2407        Solar         Oil         Oil
# ...

# %%
df.isnull().sum()
# Out:
# country                     0
# country_long                0
# name                        0
# gppd_idnr                   0
# capacity_mw                 0
# latitude                    0
# longitude                   0
# primary_fuel                0
# other_fuel1                 0
# other_fuel2                 0
# other_fuel3                 0
# commissioning_year          0
# owner                       0
# source                      0
# url                         0
# geolocation_source          0
# wepp_id                     0
# year_of_capacity_data       0
# generation_gwh_2013         0
# generation_gwh_2014         0
# generation_gwh_2015         0
# generation_gwh_2016         0
# generation_gwh_2017         0
# generation_gwh_2018         0
# generation_gwh_2019         0
# generation_data_source      0
# estimated_generation_gwh    0
# dtype: int64

# %% [markdown]
# - removed all the null values , now checking for void spaces in the dataset

# %%
df.loc[df['capacity_mw']=="0 samples"]
# Out:
# Empty DataFrame
# Columns: [country, country_long, name, gppd_idnr, capacity_mw, latitude, longitude, primary_fuel, other_fuel1, other_fuel2, other_fuel3, commissioning_year, owner, source, url, geolocation_source, wepp_id, year_of_capacity_data, generation_gwh_2013, generation_gwh_2014, generation_gwh_2015, generation_gwh_2016, generation_gwh_2017, generation_gwh_2018, generation_gwh_2019, generation_data_source, estimated_generation_gwh]
# Index: []
#
# [0 rows x 27 columns]

# %% [markdown]
# - there are no no void spaces

# %%
df.shape
# Out:
# (907, 27)

# %%
df.values
# Out:
# array([['IND', 'India', 'ACME Solar Tower', ..., 326.2237552370453,
#         'Central Electricity Authority', 326.2237552370453],
#        ['IND', 'India', 'ADITYA CEMENT WORKS', ..., 326.2237552370453,
#         'Central Electricity Authority', 326.2237552370453],
#        ['IND', 'India', 'AES Saurashtra Windfarms', ...,
#         326.2237552370453, 'Central Electricity Authority',
#         326.2237552370453],
#        ...,
#        ['IND', 'India', 'Yelisirur wind power project', ...,
#         326.2237552370453, 'Central Electricity Authority',
#         326.2237552370453],
#        ['IND', 'India', 'ZAWAR MINES', ..., 326.2237552370453,
#         'Central Electricity Authority', 326.2237552370453],
#        ['IND', 'India', 'iEnergy Theni Wind Farm', ...,
#         326.2237552370453, 'Central Electricity Authority',
#         326.2237552370453]], dtype=object)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (907, 27)

# %% [markdown]
# # LABEL ENCODING

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OrdinalEncoder
enc=OrdinalEncoder()
for i in df.columns:
    if df[i].dtypes=="object":
        df[i]=enc.fit_transform(df[i].values.reshape(-1,1))

# %%
df
# Out:
#      country  country_long   name  gppd_idnr  capacity_mw  latitude  \
# 0        0.0           0.0    0.0      657.0          2.5   28.1839
# 1        0.0           0.0    1.0      519.0         98.0   24.7663
# 2        0.0           0.0    2.0      853.0         39.2   21.9038
# 3        0.0           0.0    3.0        0.0        135.0   23.8712
# 4        0.0           0.0    4.0        1.0       1800.0   21.9603
# ..       ...           ...    ...        ...          ...       ...
# 902      0.0           0.0  902.0      491.0       1600.0   16.2949
# 903      0.0           0.0  903.0      822.0          3.0   12.8932
# 904      0.0           0.0  904.0      891.0         25.5   15.2758
# 905      0.0           0.0  905.0      539.0         80.0   24.3500
# 906      0.0           0.0  906.0      876.0         16.5    9.9344
#
#      longitude  primary_fuel  other_fuel1  other_fuel2  ...  \
# 0      73.2407           6.0          2.0          0.0  ...
# ...

# %%
df.describe()
# Out:
#        country  country_long        name   gppd_idnr  capacity_mw    latitude  \
# count    907.0         907.0  907.000000  907.000000   907.000000  907.000000
# mean       0.0           0.0  453.000000  453.000000   326.223755   21.086467
# std        0.0           0.0  261.972645  261.972645   590.085456    6.098262
# min        0.0           0.0    0.000000    0.000000     0.000000    8.168900
# 25%        0.0           0.0  226.500000  226.500000    16.725000   17.072000
# 50%        0.0           0.0  453.000000  453.000000    59.200000   21.281800
# 75%        0.0           0.0  679.500000  679.500000   385.250000   25.176450
# max        0.0           0.0  906.000000  906.000000  4760.000000   34.649000
#
#         longitude  primary_fuel  other_fuel1  other_fuel2  ...  \
# count  907.000000    907.000000   907.000000        907.0  ...
# mean    77.172109      3.206174     1.995590          0.0  ...
# std      4.976401      2.280652     0.081259          0.0  ...
# ...

# %%
df_dropped = df.drop(columns=['country', 'country_long','other_fuel2','generation_data_source'],inplace=True)

# %%
df
# Out:
#       name  gppd_idnr  capacity_mw  latitude  longitude  primary_fuel  \
# 0      0.0      657.0          2.5   28.1839    73.2407           6.0
# 1      1.0      519.0         98.0   24.7663    74.6090           1.0
# 2      2.0      853.0         39.2   21.9038    69.3732           7.0
# 3      3.0        0.0        135.0   23.8712    91.3602           2.0
# 4      4.0        1.0       1800.0   21.9603    82.4091           1.0
# ..     ...        ...          ...       ...        ...           ...
# 902  902.0      491.0       1600.0   16.2949    77.3568           1.0
# 903  903.0      822.0          3.0   12.8932    78.1654           6.0
# 904  904.0      891.0         25.5   15.2758    75.5811           7.0
# 905  905.0      539.0         80.0   24.3500    73.7477           1.0
# 906  906.0      876.0         16.5    9.9344    77.4768           7.0
#
#      other_fuel1  other_fuel3  commissioning_year  owner  ...     wepp_id  \
# ...

# %%
df_dropped = df.drop(columns=['other_fuel3', 'wepp_id','year_of_capacity_data','generation_gwh_2013','generation_gwh_2019',
                             'estimated_generation_gwh'],inplace=True)

# %%
df
# Out:
#       name  gppd_idnr  capacity_mw  latitude  longitude  primary_fuel  \
# 0      0.0      657.0          2.5   28.1839    73.2407           6.0
# 1      1.0      519.0         98.0   24.7663    74.6090           1.0
# 2      2.0      853.0         39.2   21.9038    69.3732           7.0
# 3      3.0        0.0        135.0   23.8712    91.3602           2.0
# 4      4.0        1.0       1800.0   21.9603    82.4091           1.0
# ..     ...        ...          ...       ...        ...           ...
# 902  902.0      491.0       1600.0   16.2949    77.3568           1.0
# 903  903.0      822.0          3.0   12.8932    78.1654           6.0
# 904  904.0      891.0         25.5   15.2758    75.5811           7.0
# 905  905.0      539.0         80.0   24.3500    73.7477           1.0
# 906  906.0      876.0         16.5    9.9344    77.4768           7.0
#
#      other_fuel1  commissioning_year  owner  source    url  \
# 0            2.0              2011.0  229.0   109.0  128.0
# ...

# %% [markdown]
# - cleaned all the data- columns which contains most of the null values and unwanted columns has been removed

# %% [markdown]
# # CHECKIG CORRELATION USING HEATMAP

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(22,7))
sns.heatmap(df.describe(),annot=True,linewidth=0.1,linecolor="black",fmt="0.2f")
# Out:
# <AxesSubplot:>

# %%
df.corr()['capacity_mw'].sort_values()
# Out:
# primary_fuel          -0.380395
# gppd_idnr             -0.335742
# owner                 -0.311048
# url                   -0.243830
# source                -0.242122
# commissioning_year    -0.004072
# other_fuel1            0.003105
# latitude               0.059041
# name                   0.060240
# geolocation_source     0.204865
# longitude              0.215875
# generation_gwh_2014    0.815794
# generation_gwh_2015    0.842964
# generation_gwh_2016    0.876811
# generation_gwh_2017    0.894259
# generation_gwh_2018    0.906774
# capacity_mw            1.000000
# Name: capacity_mw, dtype: float64

# %%
plt.figure(figsize=(22,7))
sns.heatmap(df.corr(),annot=True,linewidth=0.1,linecolor="black",fmt="0.2f")
# Out:
# <AxesSubplot:>

# %% [markdown]
# - many columns are highly correlated with the target variable

# %%
plt.figure(figsize=(22,7))
df.corr()["capacity_mw"].sort_values(ascending=False).drop(['capacity_mw']).plot(kind='bar',color='c')
plt.xlabel('Features',fontsize=14)
plt.ylabel('column with target names',fontsize=14)
plt.title('correlation',fontsize=18)
plt.show()

# %% [markdown]
# - we can see the correlation throgh the barplot -generation_gwth has the highest correlation

# %% [markdown]
# # CHECKING THE SKEWNESS

# %%
df.skew()
# Out:
# name                    0.000000
# gppd_idnr               0.000000
# capacity_mw             3.123576
# latitude               -0.095721
# longitude               1.130252
# primary_fuel            0.472251
# other_fuel1           -20.453120
# commissioning_year     -1.714873
# owner                   1.364406
# source                  1.827373
# url                     1.510537
# geolocation_source     -2.159841
# generation_gwh_2014     4.986588
# generation_gwh_2015     5.260778
# generation_gwh_2016     4.984874
# generation_gwh_2017     4.979870
# generation_gwh_2018     4.846091
# dtype: float64

# %%
df.plot(kind='density',subplots=True,layout=(6,11),sharex=False,legend=False,fontsize=1,figsize=(18,12))
plt.show()

# %%
df.columns
# Out:
# Index(['name', 'gppd_idnr', 'capacity_mw', 'latitude', 'longitude',
#        'primary_fuel', 'other_fuel1', 'commissioning_year', 'owner', 'source',
#        'url', 'geolocation_source', 'generation_gwh_2014',
#        'generation_gwh_2015', 'generation_gwh_2016', 'generation_gwh_2017',
#        'generation_gwh_2018'],
#       dtype='object')

# %% [markdown]
# - most of the columns are skewed

# %%
import warnings
warnings.filterwarnings('ignore')
features=['name', 'gppd_idnr', 'capacity_mw', 'latitude', 'longitude',
       'primary_fuel', 'other_fuel1', 'commissioning_year', 'owner', 'source',
       'url', 'geolocation_source', 'generation_gwh_2014',
       'generation_gwh_2015', 'generation_gwh_2016', 'generation_gwh_2017',
       'generation_gwh_2018']
plt.figure(figsize=(20,25),facecolor='white')
plotnumber=1

for column in df[features]:
    if plotnumber<=9 :
        ax=plt.subplot(3,3,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize=20)
        
    plotnumber+=1
plt.show()

# %% [markdown]
# - using powertransformer method to reduce the skewness

# %%
from sklearn.preprocessing import PowerTransformer
scaler=PowerTransformer(method='yeo-johnson')
'''
parameters:
method='box-cox' or 'yeo-johnson
'''
# Out:
# "\nparameters:\nmethod='box-cox' or 'yeo-johnson\n"

# %%
df[features]=scaler.fit_transform(df[features].values)

# %%
plt.figure(figsize=(20,25),facecolor='white')
plotnumber=1

for column in df[features]:
    if plotnumber<=9 :
        ax=plt.subplot(3,3,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize=20)
        
    plotnumber+=1
plt.show()

# %% [markdown]
# - skewness has been increased

# %% [markdown]
# # CHECKING FOR OUTLIERS

# %%
import warnings
warnings.filterwarnings('ignore')#CHECKING THE OUTLIERS
collist=df.columns.values
ncol=30
nrows=14
plt.figure(figsize=(ncol,3*ncol))
for i in range(0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(df[collist[i]],color='green',orient='h')
    plt.tight_layout()

# %%
z_scores = (df - df.mean()) / df.std()

# remove rows with z-scores greater than a threshold value (e.g., 3.0)
df_outliers_removed = df[(z_scores < 3.0).all(axis=1)]

# print the original DataFrame and the outliers removed DataFrame
print("Original DataFrame:\n", df)
print("Outliers removed DataFrame:\n", df_outliers_removed)
# Out:
# Original DataFrame:
#           name  gppd_idnr  capacity_mw  latitude  longitude  primary_fuel  \
# 0   -2.165615   0.790633    -1.695767  1.167829  -0.826778      1.171313
# 1   -2.146630   0.331335     0.193694  0.600871  -0.431721     -0.996291
# 2   -2.130340   1.397466    -0.292337  0.128413  -2.231266      1.441576
# 3   -2.115584  -2.165615     0.360998  0.452885   2.106598     -0.362170
# 4   -2.101875  -2.146630     1.649503  0.137715   1.144189     -0.996291
# ..        ...        ...          ...       ...        ...           ...
# 902  1.542553   0.234021     1.593509 -0.789835   0.238099     -0.996291
# 903  1.545490   1.304428    -1.615576 -1.340861   0.408358      1.171313
# 904  1.548426   1.510186    -0.522773 -0.955438  -0.177302      1.441576
# 905  1.551361   0.399915     0.086915  0.532017  -0.675056     -0.996291
# 906  1.554295   1.465861    -0.755891 -1.815567   0.264067      1.441576
#
#      other_fuel1  commissioning_year     owner    source       url  \
# ...

# %% [markdown]
# - OUTLIERS HAS BEEN REMOVED AND IMPROVED USING ZSCORE METHOD

# %% [markdown]
# - SEPERATING FEATURES AND TARGETS

# %% [markdown]
# # STARTING WITH THE REGRESSION MODEL(capacity_mw)

# %%
features=df.drop("capacity_mw",axis=1)
target=df['capacity_mw']

# %%
from sklearn.preprocessing import MinMaxScaler
nms=MinMaxScaler()
from sklearn.linear_model import LinearRegression 
lr=LinearRegression()
from sklearn.metrics import r2_score 
from sklearn.model_selection import train_test_split

# %%
for i in range(0,100):
    features_train,features_test,target_train,target_test=train_test_split(features,target,test_size=0.2,random_state=i)
    lr.fit(features_train,target_train)
    pred_train=lr.predict(features_train)
    pred_test=lr.predict(features_test)
    print(f"at random state {i}, the training accuracy is:- {r2_score(target_train,pred_train)}")
    print(f"at random state {i}, the testing accuracy is:- {r2_score(target_test,pred_test)}")
# Out:
# at random state 0, the training accuracy is:- 0.7184217733358074
# at random state 0, the testing accuracy is:- 0.7601223446989572
# at random state 1, the training accuracy is:- 0.739817807077412
# at random state 1, the testing accuracy is:- 0.6588597045524038
# at random state 2, the training accuracy is:- 0.7243760094121441
# at random state 2, the testing accuracy is:- 0.7309917234215859
# at random state 3, the training accuracy is:- 0.7226780264860772
# at random state 3, the testing accuracy is:- 0.7399724609538161
# at random state 4, the training accuracy is:- 0.7291955028311046
# at random state 4, the testing accuracy is:- 0.7104104421684847
# at random state 5, the training accuracy is:- 0.7224935932743406
# at random state 5, the testing accuracy is:- 0.7389746297219639
# at random state 6, the training accuracy is:- 0.7394931009957217
# at random state 6, the testing accuracy is:- 0.6320562461996395
# at random state 7, the training accuracy is:- 0.7216359079601476
# ...

# %% [markdown]
# RANDOM STATE 65 LOOKS GOOD SINCE THE RATION BTW THE TRAINING AN TESTING SCORE IS CLOSE

# %%
features_train,features_test,target_train,target_test=train_test_split(features,target,test_size=0.2,random_state=98)

# %%
lr.fit(features_train,target_train)
# Out:
# LinearRegression()

# %%
pred_test=lr.predict(features_test)

# %%
print(r2_score(target_test,pred_test))
# Out:
# 0.8055189806731284

# %% [markdown]
# # CROSS VALIDATION SCORE

# %%
from sklearn.model_selection import cross_val_score
Train_accuracy=r2_score(target_train,pred_train)
Test_accuracy=r2_score(target_test,pred_test)

for j in range(2,10):
    cv_score=cross_val_score(lr,features,target,cv=j)
    cv_mean=cv_score.mean()
    print(f"at cross fold {j} the cv score is  {cv_mean} and accuracy score for training is {Train_accuracy} and accuracy for the testing is {Test_accuracy}")
    print("\n")
# Out:
# at cross fold 2 the cv score is  0.6966262955226947 and accuracy score for training is -0.7840163663628545 and accuracy for the testing is 0.8055189806731284
#
#
# at cross fold 3 the cv score is  0.7004392016583841 and accuracy score for training is -0.7840163663628545 and accuracy for the testing is 0.8055189806731284
#
#
# at cross fold 4 the cv score is  0.7078210552893245 and accuracy score for training is -0.7840163663628545 and accuracy for the testing is 0.8055189806731284
#
#
# at cross fold 5 the cv score is  0.7057246423242972 and accuracy score for training is -0.7840163663628545 and accuracy for the testing is 0.8055189806731284
#
#
# at cross fold 6 the cv score is  0.7006169184813297 and accuracy score for training is -0.7840163663628545 and accuracy for the testing is 0.8055189806731284
#
#
# at cross fold 7 the cv score is  0.6993120355224989 and accuracy score for training is -0.7840163663628545 and accuracy for the testing is 0.8055189806731284
#
#
# ...

# %% [markdown]
# # REGULARIZATION

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.linear_model import Lasso
parameters={'alpha':[.0001,.001,.01,.1,1,10],
           'random_state':list(range(0,10))}
ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(features_train,target_train)
print(clf.best_params_)
# Out:
# {'alpha': 0.01, 'random_state': 0}

# %% [markdown]
# - FINAL TRAINING

# %%
ls=Lasso(alpha=0.01,random_state=0)
ls.fit(features_train,target_train)
ls_score_training=ls.score(features_train,target_train)
pred_ls=ls.predict(features_test)
ls_score_training*100
# Out:
# 70.01839470285219

# %%
pred_ls=ls.predict(features_test)
lss=r2_score(target_test,pred_ls)

# %%
lss
# Out:
# 0.8085641778778369

# %%
cv_score=cross_val_score(ls,features,target,cv=4)
cv_means=cv_score.mean()
cv_mean*100
# Out:
# 70.2144752235784

# %% [markdown]
# - hence the model is not overfitted

# %% [markdown]
# # ENSEMBLE TECHNIQUES

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

parameters={'criterion':['mse','mae'],
           'max_features':["auto","sqrt","log2"]}

rf=RandomForestRegressor()
clf=GridSearchCV(rf,parameters)
clf.fit(features_train,target_train)

print(clf.best_params_)
# Out:
# {'criterion': 'mse', 'max_features': 'log2'}

# %%
rf=RandomForestRegressor(criterion="mse",max_features="log2")
rf.fit(features_train,target_train)
rf.score(features_train,target_train)
pred_decision=rf.predict(features_test)

rfs=r2_score(target_test,pred_decision)
print('R2 score:',rfs*100)

rfscore=cross_val_score(rf,features,target,cv=5)
rfs=rfscore.mean()
print("cross val score:",rfs*100)
# Out:
# R2 score: 88.62960219752118
# cross val score: 79.10586153922219

# %% [markdown]
# - MODEL ACCURACY AND CROSS VALIDATION IS GOOD

# %% [markdown]
# # SAVING THE MODEL

# %%
import pickle
filename='churn.pkl'
pickle.dump(rf,open(filename,'wb'))
