# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("https://raw.githubusercontent.com/dsrscientist/dataset1/master/census_income.csv")
df.head()
# Out:
#    Age          Workclass  Fnlwgt   Education  Education_num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
# 3   28            Private  338409   Bachelors             13
# 4   37            Private  284582     Masters             14
#
#         Marital_status          Occupation    Relationship    Race      Sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    Capital_gain  Capital_loss  Hours_per_week  Native_country  Income
# 0             0             0              13   United-States   <=50K
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['Age', 'Workclass', 'Fnlwgt', 'Education', 'Education_num',
#        'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex',
#        'Capital_gain', 'Capital_loss', 'Hours_per_week', 'Native_country',
#        'Income'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Age               0
# Workclass         0
# Fnlwgt            0
# Education         0
# Education_num     0
# Marital_status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Capital_gain      0
# Capital_loss      0
# Hours_per_week    0
# Native_country    0
# Income            0
# dtype: int64

# %% [markdown]
# - NO NULL

# %%
df.dtypes
# Out:
# Age                int64
# Workclass         object
# Fnlwgt             int64
# Education         object
# Education_num      int64
# Marital_status    object
# Occupation        object
# Relationship      object
# Race              object
# Sex               object
# Capital_gain       int64
# Capital_loss       int64
# Hours_per_week     int64
# Native_country    object
# Income            object
# dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn as sns
df["Income"].hist(grid=False)
plt.title("No VS Yes")
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OrdinalEncoder
enc=OrdinalEncoder()
for i in df.columns:
    if df[i].dtypes=="object":
        df[i]=enc.fit_transform(df[i].values.reshape(-1,1))

# %%
df
# Out:
#        Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0       50        6.0   83311        9.0             13             2.0
# 1       38        4.0  215646       11.0              9             0.0
# 2       53        4.0  234721        1.0              7             2.0
# 3       28        4.0  338409        9.0             13             2.0
# 4       37        4.0  284582       12.0             14             2.0
# ...    ...        ...     ...        ...            ...             ...
# 32555   27        4.0  257302        7.0             12             2.0
# 32556   40        4.0  154374       11.0              9             2.0
# 32557   58        4.0  151910       11.0              9             6.0
# 32558   22        4.0  201490       11.0              9             4.0
# 32559   52        5.0  287927       11.0              9             2.0
#
#        Occupation  Relationship  Race  Sex  Capital_gain  Capital_loss  \
# ...

# %% [markdown]
# - CHECKING THE DISTRIBUTION

# %%
import seaborn as sns
sns.scatterplot(x="Age",y="Income",data=df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Income'>

# %%
sns.scatterplot(x="Workclass",y="Income",data=df)
# Out:
# <AxesSubplot:xlabel='Workclass', ylabel='Income'>

# %%
sns.scatterplot(x="Fnlwgt",y="Income",data=df)
# Out:
# <AxesSubplot:xlabel='Fnlwgt', ylabel='Income'>

# %%
sns.scatterplot(x="Education",y="Income",data=df)
# Out:
# <AxesSubplot:xlabel='Education', ylabel='Income'>

# %%
sns.scatterplot(x="Education_num",y="Income",data=df)
# Out:
# <AxesSubplot:xlabel='Education_num', ylabel='Income'>

# %%
sns.scatterplot(x="Marital_status",y="Income",data=df)
# Out:
# <AxesSubplot:xlabel='Marital_status', ylabel='Income'>

# %%
sns.scatterplot(x="Occupation",y="Income",data=df)
# Out:
# <AxesSubplot:xlabel='Occupation', ylabel='Income'>

# %%
sns.scatterplot(x="Relationship",y="Income",data=df)
# Out:
# <AxesSubplot:xlabel='Relationship', ylabel='Income'>

# %%
sns.scatterplot(x="Race",y="Income",data=df)
# Out:
# <AxesSubplot:xlabel='Race', ylabel='Income'>

# %%
sns.scatterplot(x="Sex",y="Income",data=df)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Income'>

# %%
sns.scatterplot(x="Capital_gain",y="Income",data=df)
# Out:
# <AxesSubplot:xlabel='Capital_gain', ylabel='Income'>

# %%
sns.scatterplot(x="Capital_loss",y="Income",data=df)
# Out:
# <AxesSubplot:xlabel='Capital_loss', ylabel='Income'>

# %%
sns.scatterplot(x="Hours_per_week",y="Income",data=df)
# Out:
# <AxesSubplot:xlabel='Hours_per_week', ylabel='Income'>

# %%
sns.scatterplot(x="Native_country",y="Income",data=df)
# Out:
# <AxesSubplot:xlabel='Native_country', ylabel='Income'>

# %% [markdown]
# - ALMOST ALL COLUMNS ARE EQUALLY DISTRIBUTED

# %% [markdown]
# - CORRELATION

# %%
df.corr()
# Out:
#                      Age  Workclass    Fnlwgt  Education  Education_num  \
# Age             1.000000   0.003786 -0.076646  -0.010508       0.036527
# Workclass       0.003786   1.000000 -0.016587   0.023537       0.052015
# Fnlwgt         -0.076646  -0.016587  1.000000  -0.028156      -0.043159
# Education      -0.010508   0.023537 -0.028156   1.000000       0.359172
# Education_num   0.036527   0.052015 -0.043159   0.359172       1.000000
# Marital_status -0.266292  -0.064798  0.028184  -0.038398      -0.069338
# Occupation     -0.020946   0.255004  0.001554  -0.021274       0.109748
# Relationship   -0.263698  -0.090449  0.008922  -0.010879      -0.094145
# Race            0.028718   0.049720 -0.021278   0.014135       0.031825
# Sex             0.088832   0.095942  0.026882  -0.027349       0.012256
# Capital_gain    0.077674   0.033828  0.000437   0.030047       0.122627
# Capital_loss    0.057775   0.012231 -0.010259   0.016744       0.079932
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(),annot=True,linewidth=0.5,linecolor="black",fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# - FROM THR ABOVE HEATMAP DISTRIBUTION ITS CLEAR THA AGE, EDUCATION_NUM, SEX,CAPITAL_GAIN,HOURS_PER_WEEK,CAPITAL_LOSS HAS A STRONG CORRELATION

# %%
df.describe()
# Out:
#                 Age     Workclass        Fnlwgt     Education  Education_num  \
# count  32560.000000  32560.000000  3.256000e+04  32560.000000   32560.000000
# mean      38.581634      3.868796  1.897818e+05     10.298249      10.080590
# std       13.640642      1.455879  1.055498e+05      3.870317       2.572709
# min       17.000000      0.000000  1.228500e+04      0.000000       1.000000
# 25%       28.000000      4.000000  1.178315e+05      9.000000       9.000000
# 50%       37.000000      4.000000  1.783630e+05     11.000000      10.000000
# 75%       48.000000      4.000000  2.370545e+05     12.000000      12.000000
# max       90.000000      8.000000  1.484705e+06     15.000000      16.000000
#
#        Marital_status    Occupation  Relationship          Race           Sex  \
# count    32560.000000  32560.000000  32560.000000  32560.000000  32560.000000
# mean         2.611794      6.572912      1.446376      3.665848      0.669195
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32560 non-null  int64
#  1   Workclass       32560 non-null  float64
#  2   Fnlwgt          32560 non-null  int64
#  3   Education       32560 non-null  float64
#  4   Education_num   32560 non-null  int64
#  5   Marital_status  32560 non-null  float64
#  6   Occupation      32560 non-null  float64
#  7   Relationship    32560 non-null  float64
#  8   Race            32560 non-null  float64
#  9   Sex             32560 non-null  float64
#  10  Capital_gain    32560 non-null  int64
#  11  Capital_loss    32560 non-null  int64
#  12  Hours_per_week  32560 non-null  int64
#  13  Native_country  32560 non-null  float64
#  14  Income          32560 non-null  float64
# dtypes: float64(9), int64(6)
# memory usage: 3.7 MB

# %% [markdown]
# # CHECKING THE OUTLIERS

# %%
import warnings
warnings.filterwarnings('ignore')#CHECKING THE OUTLIERS
collist=df.columns.values
ncol=30
nrows=14
plt.figure(figsize=(ncol,3*ncol))
for i in range(0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(df[collist[i]],color='green',orient='h')
    plt.tight_layout()

# %% [markdown]
# - MOST OF THE COLUMNS CONSIST OUTLIERS

# %%
df.skew()
# Out:
# Age                0.558738
# Workclass         -0.752280
# Fnlwgt             1.446972
# Education         -0.934063
# Education_num     -0.311630
# Marital_status    -0.013448
# Occupation         0.114540
# Relationship       0.786784
# Race              -2.435332
# Sex               -0.719244
# Capital_gain      11.953690
# Capital_loss       4.594549
# Hours_per_week     0.227636
# Native_country    -3.658235
# Income             1.212383
# dtype: float64

# %%
features=['Age', 'Workclass', 'Fnlwgt', 'Education', 'Education_num',
       'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex',
       'Capital_gain', 'Capital_loss', 'Hours_per_week', 'Native_country']

# %%
plt.figure(figsize=(20,25),facecolor='white')
plotnumber=1

for column in df[features]:
    if plotnumber<=9 :
        ax=plt.subplot(3,3,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize=20)
        
    plotnumber+=1
plt.show()

# %% [markdown]
# - IT HAS UNEVEN DISTRIBUTION

# %% [markdown]
# - REMOVING THE OUTLIERS

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(df))
z.shape
# Out:
# (32560, 15)

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([    3,     9,    10, ..., 32532, 32550, 32552], dtype=int64), array([13, 12,  8, ...,  8,  8,  8], dtype=int64))

# %%
len(np.where(z>3)[0])
# Out:
# 5667

# %%
df_new=df[(z<3).all(axis=1)]
print("Old Dataframe",df.shape)
print("New DataFrame",df_new.shape)
print("Total_dropped_rows",df.shape[0]-df_new.shape[0])
# Out:
# Old Dataframe (32560, 15)
# New DataFrame (27417, 15)
# Total_dropped_rows 5143

# %%
#independent column
x=df_new.iloc[:,:-1]
#target
y=df_new.iloc[:,-1]

# %%
from sklearn.preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')

# %%
x
# Out:
# array([[ 0.92336406,  1.64526411, -1.12131617, ..., -0.04054646,
#         -2.25001838,  0.15400372],
#        [ 0.12023351,  0.02043118,  0.405265  , ..., -0.04054646,
#         -0.02842846,  0.15400372],
#        [ 1.10084567,  0.02043118,  0.58748477, ..., -0.04054646,
#         -0.02842846,  0.15400372],
#        ...,
#        [ 1.38020451,  0.02043118, -0.25770629, ..., -0.04054646,
#         -0.02842846,  0.15400372],
#        [-1.32091732,  0.02043118,  0.26573656, ..., -0.04054646,
#         -1.7403565 ,  0.15400372],
#        [ 1.0425604 ,  0.80204545,  1.06584868, ..., -0.04054646,
#         -0.02842846,  0.15400372]])

# %%
pd.DataFrame(x).skew()
# Out:
# 0      0.008656
# 1      0.036929
# 2      0.014425
# 3     -0.051002
# 4     -0.118886
# 5     -0.044351
# 6     -0.041958
# 7      0.057919
# 8     -2.533432
# 9     -0.684115
# 10     3.069625
# 11    24.623864
# 12     0.016155
# 13     5.689972
# dtype: float64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
from sklearn.metrics import accuracy_score

# %%
#SPLITING THE DATAFRAME 
maxAccu=0
maxRS=0
for i in range(0,1000):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=i,test_size=0.20)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)#making predictions on my x train
    pred_test=lr.predict(x_test)#"""""""""""""""""""""""""" x test
    if round(accuracy_score(y_train,pred_train)*100,1)==round(accuracy_score(y_test,pred_test)*100,1): #comparing these two values
        print("At random state",i,"the model preforms very well")
        print("At random state:-",i)
        print("Training Accuracy_Score is:-",accuracy_score(y_train,pred_train)*100)
        print("Testing accuracy_score is:-",accuracy_score(y_test,pred_test)*100,'\n')
# Out:
# At random state 18 the model preforms very well
# At random state:- 18
# Training Accuracy_Score is:- 82.88423836228515
# Testing accuracy_score is:- 82.89569657184536
#
# At random state 65 the model preforms very well
# At random state:- 65
# Training Accuracy_Score is:- 82.89791638170793
# Testing accuracy_score is:- 82.85922684172137
#
# At random state 76 the model preforms very well
# At random state:- 76
# Training Accuracy_Score is:- 82.9298317603611
# Testing accuracy_score is:- 82.91393143690736
#
# At random state 103 the model preforms very well
# At random state:- 103
# Training Accuracy_Score is:- 82.9389504399763
# Testing accuracy_score is:- 82.91393143690736
#
# At random state 142 the model preforms very well
# At random state:- 142
# Training Accuracy_Score is:- 82.83408562440158
# Testing accuracy_score is:- 82.82275711159738
#
# At random state 146 the model preforms very well
# At random state:- 146
# Training Accuracy_Score is:- 82.97086581862946
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=146)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,pred_test))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.78      0.85      0.81      4255
#          1.0       0.24      0.16      0.19      1229
#
#     accuracy                           0.70      5484
#    macro avg       0.51      0.50      0.50      5484
# weighted avg       0.66      0.70      0.67      5484

# %% [markdown]
# - CROSS VALIDATION SCORE FOR LOGISTIC REGRESSION

# %%
pred_lr=lr.predict(x_test)
from sklearn.model_selection import cross_val_score
lss=accuracy_score(y_test,pred_lr)
for j in range(2,10):
    lsscore= cross_val_score(lr,x,y,cv=j)
    lsc=lsscore.mean()
    print("At cv:-",j)
    print("Cross Validation score is :-",lsc*100)
    print("accuracy_score is :-",lss*100)
    print("\n")
# Out:
# At cv:- 2
# Cross Validation score is :- 82.87924107543382
# accuracy_score is :- 82.96863603209337
#
#
# At cv:- 3
# Cross Validation score is :- 82.84640916219863
# accuracy_score is :- 82.96863603209337
#
#
# At cv:- 4
# Cross Validation score is :- 82.86830436719431
# accuracy_score is :- 82.96863603209337
#
#
# At cv:- 5
# Cross Validation score is :- 82.89748513840205
# accuracy_score is :- 82.96863603209337
#
#
# At cv:- 6
# Cross Validation score is :- 82.87194854359741
# accuracy_score is :- 82.96863603209337
#
#
# At cv:- 7
# Cross Validation score is :- 82.89019070415632
# accuracy_score is :- 82.96863603209337
#
#
# At cv:- 8
# Cross Validation score is :- 82.90844757926534
# accuracy_score is :- 82.96863603209337
#
#
# At cv:- 9
# Cross Validation score is :- 82.87562005226883
# accuracy_score is :- 82.96863603209337

# %%
lsscore_selected=cross_val_score(lr,x,y,cv=9).mean()
print("The cv score is:",lsscore_selected,"\n the accuracy score is:",lss)
# Out:
# The cv score is: 0.8287562005226883
#  the accuracy score is: 0.8296863603209337

# %% [markdown]
# # AUC ROC CURVE

# %%
from sklearn.metrics import roc_curve,auc
fpr,tpr,thresholds=roc_curve(pred_test,y_test)
roc_auc=auc(fpr,tpr)

plt.figure()
plt.plot(fpr,tpr,color='darkorange',lw=10,label='ROC curve (area=%0.2f)'%roc_auc)
plt.plot([0,1],[0,1],color='navy',lw=10,linestyle='--')
plt.xlim([0.0,1.0])
plt.ylim([0.0,1.05])
plt.xlabel('false positive rate')
plt.ylabel('true positive rate')
plt.title('reciever operating characteristic ')
plt.legend(loc="lower right")
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x=df.drop('Income',axis=1)
X_scaled=scaler.fit_transform(x)

# %%
from sklearn.decomposition import PCA 
pca=PCA(n_components=14)
new_pcomp=pca.fit_transform(X_scaled)
princi_comp=pd.DataFrame(new_pcomp,columns=['PC1','PC2','PC3','PC4','PC5','PC6','PC7','PC8','PC9','PC10','PC11','PC12','PC13','PC14'])
princi_comp
# Out:
#             PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0      0.822675 -0.046165  0.503121 -0.711946 -0.861145  0.022053 -0.606163
# 1      0.941992  0.476391  0.502271 -0.351364 -0.120438  0.219372  0.515953
# 2      0.336373  2.833701 -0.063946  0.895840 -0.728406  0.087420 -0.017022
# 3     -2.120036 -0.587171 -2.077763  4.047523 -0.401611 -0.445993  0.936115
# 4     -1.438047 -1.982091  0.417235  0.070822 -0.191678  0.217877  1.477649
# ...         ...       ...       ...       ...       ...       ...       ...
# 32555 -1.646840 -1.084351 -1.256651 -0.507581 -1.029669  0.161800  1.470221
# 32556  0.946319  0.500195  0.196419 -0.582741  0.061532  0.116931 -0.418798
# 32557 -2.040065 -0.458982  0.909964 -0.355556 -0.536408  0.127885 -0.136060
# 32558 -1.696135  0.172783  0.151577 -0.935993  1.136757  0.251041 -0.376712
# 32559 -1.145815 -0.873633  0.445674  0.405038 -1.321061  1.533334  2.199979
#
# ...

# %%
df['Income']=df['Income'].replace({'M':1,'B':0})#replacing for the coputer to understand
y=df['Income']

# %%
x_train,x_test,y_train,y_test=train_test_split(princi_comp,y,test_size=0.25,random_state=355)

# %%
def print_score(clf,x_train,x_test,y_train,y_test,train=True):
    if train:
        y_pred=clf.predict(x_train)
        print("\n===============Train Result==================")
        print(f"Accuracy Score: {accuracy_score(y_train,y_pred)*100:2f}%")
    elif train==False:
        
        pred=clf.predict(x_test)
        
        print('\n==================Test Result===============')
        
        print(f"Accuracy Score:{accuracy_score(y_test,pred)*100:2f}%")
            
        print('\n \n Test classification report \n ',classification_report(y_test,pred,digits=2))

# %%
from sklearn.svm import SVC
svc=SVC()
svc.fit(x_train,y_train)
print_score(svc,x_train,x_test,y_train,y_test,train=True)
print_score(svc,x_train,x_test,y_train,y_test,train=False)
# Out:
# ===============Train Result==================
# Accuracy Score: 85.778051%
#
# ==================Test Result===============
# Accuracy Score:84.373464%
#
#
#  Test classification report
#                 precision    recall  f1-score   support
#
#          0.0       0.87      0.94      0.90      6160
#          1.0       0.74      0.55      0.63      1980
#
#     accuracy                           0.84      8140
#    macro avg       0.80      0.75      0.77      8140
# weighted avg       0.84      0.84      0.84      8140

# %% [markdown]
# - HENCE USING PCA AND SVC THE FI-SCORE HAS BEEN INCREASED TO 90%

# %%
from sklearn.ensemble import RandomForestClassifier
rf_model=RandomForestClassifier(criterion='entropy',max_depth=15,max_features='sqrt',min_samples_leaf=1,min_samples_split=3,n_estimators=14)
rf_model.fit(x_train,y_train)
y_pred=rf_model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
rf_model_train_acc=accuracy_score(y_train,rf_model.predict(x_train))
rf_model_test_acc=accuracy_score(y_test,y_pred)

print("Training Accuracy:",rf_model_train_acc)
print("Test Accuracy:",rf_model_test_acc)
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# Training Accuracy: 0.9386977886977887
# Test Accuracy: 0.8395577395577396
# [[5697  463]
#  [ 843 1137]]
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.92      0.90      6160
#          1.0       0.71      0.57      0.64      1980
#
#     accuracy                           0.84      8140
#    macro avg       0.79      0.75      0.77      8140
# weighted avg       0.83      0.84      0.83      8140

# %%
from sklearn.model_selection import GridSearchCV
grid_params={
    'criterion':['gini','entropy'],
    'max_depth':[3,5,7,10],
    'min_samples_split':range(2,10,1),
    'min_samples_leaf':range(2,10,1)
}
grid_search=GridSearchCV(rf_model,grid_params,cv=5,n_jobs=-1,verbose=1)
grid_search.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 512 candidates, totalling 2560 fits
# GridSearchCV(cv=5,
#              estimator=RandomForestClassifier(criterion='entropy', max_depth=15,
#                                               max_features='sqrt',
#                                               min_samples_split=3,
#                                               n_estimators=14),
#              n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [3, 5, 7, 10],
#                          'min_samples_leaf': range(2, 10),
#                          'min_samples_split': range(2, 10)},
#              verbose=1)

# %%
print(grid_search.best_params_)
print(grid_search.best_score_)
# Out:
# {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 6}
# 0.8464782964782964

# %%
rf_model=grid_search.best_estimator_
y_pred=rf_model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
rf_model_train_acc=accuracy_score(y_train,rf_model.predict(x_train))
rf_model_test_acc=accuracy_score(y_test,y_pred)

print("Training Accuracy:",rf_model_train_acc)
print("Test Accuracy:",rf_model_test_acc)
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# Training Accuracy: 0.8662571662571663
# Test Accuracy: 0.8428746928746929
# [[5815  345]
#  [ 934 1046]]
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.94      0.90      6160
#          1.0       0.75      0.53      0.62      1980
#
#     accuracy                           0.84      8140
#    macro avg       0.81      0.74      0.76      8140
# weighted avg       0.83      0.84      0.83      8140

# %% [markdown]
# - HENCE WE CAN TAKE RANDOM FOREST AS THE BEST MODEL

# %% [markdown]
# # SAVING THE MODEL

# %%
rf=RandomForestClassifier
import pickle
filename='census_income.pkl'
pickle.dump(rf,open(filename,'wb'))
